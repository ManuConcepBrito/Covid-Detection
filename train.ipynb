# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
from models.miniNet import MiniNet
from utils.outputEvaluation import binary_acc
import matplotlib.pyplot as plt
from torchvision import transforms
from utils.train import TrainClass
from datasets.covidDataset import CovidDataset

# %% [markdown]
# ### Load Data

# %%
covid_data_train = CovidDataset("utils", phase='train', transform=transforms.FiveCrop((100,100)))
covid_data_val = CovidDataset("utils", phase='val', transform=transforms.FiveCrop((100,100)))
covid_data_test = CovidDataset("utils", phase='test', transform=transforms.FiveCrop((100,100)))

# %% [markdown]
# ### Perform training
# Perform training on Binary Cross Entropy Loss

# %%
net = MiniNet()
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
train_instance = TrainClass(net, 
                            criterion, 
                            optimizer,
                           binary_acc,
                           covid_data_train,
                           val_data=covid_data_val,
                           epochs=25,
                           print_every=500,
                           )
losses = train_instance.train()
# Out:
# Training loss iter 500 loss: 0.658
# Saving best model at 64.286
#
# Validation metric: 64.286
# Training loss iter 1000 loss: 0.643
# Saving best model at 67.500
#
# Validation metric: 67.500
# Training loss iter 1500 loss: 0.620
# Saving best model at 68.571
#
# Validation metric: 68.571
# Training loss iter 2000 loss: 0.523
# Saving best model at 73.929
#
# Validation metric: 73.929
# Training loss iter 2500 loss: 0.541
# Saving best model at 75.714
#
# Validation metric: 75.714
# Training loss iter 3000 loss: 0.543
# Saving best model at 77.500
#
# Validation metric: 77.500
# Training loss iter 3500 loss: 0.448
#
# Validation metric: 74.286
# Training loss iter 4000 loss: 0.477
# Saving best model at 79.286
#
# Validation metric: 79.286
# Training loss iter 4500 loss: 0.518
#
# Validation metric: 77.500
# Training loss iter 5000 loss: 0.394
#
# Validation metric: 72.857
# Training loss iter 5500 loss: 0.419
#
# Validation metric: 79.286
# Training loss iter 6000 loss: 0.476
#
# Validation metric: 77.500
# Training loss iter 6500 loss: 0.367
#
# Validation metric: 77.857
# Training loss iter 7000 loss: 0.378
#
# Validation metric: 77.143
# Training loss iter 7500 loss: 0.431
#
# Validation metric: 78.929
# Training loss iter 8000 loss: 0.320
#
# Validation metric: 75.357
# Training loss iter 8500 loss: 0.340
#
# Validation metric: 79.286
# Training loss iter 9000 loss: 0.386
# Saving best model at 81.786
#
# Validation metric: 81.786
# Training loss iter 9500 loss: 0.265
#
# Validation metric: 77.500
# Training loss iter 10000 loss: 0.334
#
# Validation metric: 77.500
# Training loss iter 10500 loss: 0.338
#
# Validation metric: 80.714
# Training loss iter 11000 loss: 0.234
#
# Validation metric: 78.214
# Training loss iter 11500 loss: 0.373
#
# Validation metric: 80.357
# Training loss iter 12000 loss: 0.310
#
# Validation metric: 81.071
# Training loss iter 12500 loss: 0.199
#
# Validation metric: 80.714
# Training loss iter 13000 loss: 0.196
# Saving best model at 82.143
#
# Validation metric: 82.143
# Training loss iter 13500 loss: 0.223
#
# Validation metric: 82.143
# Training loss iter 14000 loss: 0.175
#
# Validation metric: 79.286
# Training loss iter 14500 loss: 0.219
#
# Validation metric: 80.357
# Training loss iter 15000 loss: 0.212
# Saving best model at 83.214
#
# Validation metric: 83.214
# Training loss iter 15500 loss: 0.150
#
# Validation metric: 78.571
# Training loss iter 16000 loss: 0.181
#
# Validation metric: 78.571
# Training loss iter 16500 loss: 0.213
# Saving best model at 86.071
#
# Validation metric: 86.071
# Training loss iter 17000 loss: 0.127
#
# Validation metric: 81.429
# Training loss iter 17500 loss: 0.128
#
# Validation metric: 80.714
# Training loss iter 18000 loss: 0.221
#
# Validation metric: 84.286
# Training loss iter 18500 loss: 0.127
#
# Validation metric: 78.929
# Training loss iter 19000 loss: 0.132
#
# Validation metric: 79.286
# Training loss iter 19500 loss: 0.150
# Saving best model at 87.143
#
# Validation metric: 87.143
# Training loss iter 20000 loss: 0.081
#
# Validation metric: 81.786
# Training loss iter 20500 loss: 0.131
#
# Validation metric: 83.571
# Training loss iter 21000 loss: 0.100
#
# Validation metric: 85.714
# Training loss iter 21500 loss: 0.095
#
# Validation metric: 82.857
# Training loss iter 22000 loss: 0.117
#
# Validation metric: 81.429
# Training loss iter 22500 loss: 0.166
#
# Validation metric: 83.929
# Training loss iter 23000 loss: 0.071
#
# Validation metric: 81.786
# Training loss iter 23500 loss: 0.102
#
# Validation metric: 78.214
# Training loss iter 24000 loss: 0.077
#
# Validation metric: 84.286
# Training loss iter 24500 loss: 0.028
#
# Validation metric: 83.214
# Training loss iter 25000 loss: 0.134
#
# Validation metric: 82.857
# Training loss iter 25500 loss: 0.141
#
# Validation metric: 83.929
# Training loss iter 26000 loss: 0.037
#
# Validation metric: 86.429
# Training loss iter 26500 loss: 0.079
#
# Validation metric: 84.286
# Training loss iter 27000 loss: 0.078
#
# Validation metric: 82.857
# Training loss iter 27500 loss: 0.039
#
# Validation metric: 83.571
# Training loss iter 28000 loss: 0.042
#
# Validation metric: 80.714
# Training loss iter 28500 loss: 0.068
#
# Validation metric: 81.429
# Training loss iter 29000 loss: 0.018
#
# Validation metric: 82.500
# Training loss iter 29500 loss: 0.119
#
# Validation metric: 81.429
# Training loss iter 30000 loss: 0.073
#
# Validation metric: 85.000
# Training loss iter 30500 loss: 0.051
#
# Validation metric: 82.500
# Training loss iter 31000 loss: 0.075
#
# Validation metric: 83.929
# Training loss iter 31500 loss: 0.029
#
# Validation metric: 81.786
# Training loss iter 32000 loss: 0.033
#
# Validation metric: 81.429
# Training loss iter 32500 loss: 0.100
#
# Validation metric: 81.429
# Training loss iter 33000 loss: 0.084
#
# Validation metric: 83.571
# Training loss iter 33500 loss: 0.072
#
# Validation metric: 83.571
# Training loss iter 34000 loss: 0.025
# Saving best model at 87.500
#
# Validation metric: 87.500
# Training loss iter 34500 loss: 0.024
#
# Validation metric: 80.357
# Training loss iter 35000 loss: 0.047
#
# Validation metric: 83.214
# Training loss iter 35500 loss: 0.084
#
# Validation metric: 82.857
# Training loss iter 36000 loss: 0.079
#
# Validation metric: 85.357
# Training loss iter 36500 loss: 0.042
#
# Validation metric: 83.929
# Training loss iter 37000 loss: 0.068
#
# Validation metric: 77.143
# Training loss iter 37500 loss: 0.059
#
# Validation metric: 83.214
# Finished Training
