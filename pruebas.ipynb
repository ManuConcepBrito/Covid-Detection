# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
from models.miniNet import MiniNet
from utils.outputEvaluation import binary_acc
import matplotlib.pyplot as plt
from torchvision import transforms
from utils.train import TrainClass
from datasets.covidDataset import CovidDataset

# %% [markdown]
# ### Load Data

# %%
covid_data_train = CovidDataset("utils", phase='train', transform=transforms.FiveCrop((100,100)))
covid_data_val = CovidDataset("utils", phase='val', transform=transforms.FiveCrop((100,100)))
covid_data_test = CovidDataset("utils", phase='test', transform=transforms.FiveCrop((100,100)))

# %% [markdown]
# ### Perform training
# Perform training on Binary Cross Entropy Loss

# %%
net = MiniNet()
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
train_instance = TrainClass(net, 
                            criterion, 
                            optimizer,
                           binary_acc,
                           covid_data_train,
                           val_data=covid_data_val,
                           epochs=25,
                           print_every=500,
                           )
losses = train_instance.train()
# Out:
# Training loss iter 500 loss: 0.695
# Saving best model at 63.929
#
# Validation metric: 63.929
# Training loss iter 1000 loss: 0.718
#
# Validation metric: 63.571
# Training loss iter 1500 loss: 0.701
#
# Validation metric: 62.500
# Training loss iter 2000 loss: 0.679
#
# Validation metric: 63.571
# Training loss iter 2500 loss: 0.729
#
# Validation metric: 58.571
# Training loss iter 3000 loss: 0.542
#
# Validation metric: 53.214
# Training loss iter 3500 loss: 0.635
# Saving best model at 71.786
#
# Validation metric: 71.786
# Training loss iter 4000 loss: 0.632
#
# Validation metric: 65.714
# Training loss iter 4500 loss: 0.540
#
# Validation metric: 71.071
# Training loss iter 5000 loss: 0.546
# Saving best model at 75.357
#
# Validation metric: 75.357
# Training loss iter 5500 loss: 0.561
#
# Validation metric: 69.286
# Training loss iter 6000 loss: 0.451
#
# Validation metric: 71.786
# Training loss iter 6500 loss: 0.480
# Saving best model at 79.286
#
# Validation metric: 79.286
# Training loss iter 7000 loss: 0.484
#
# Validation metric: 75.000
# Training loss iter 7500 loss: 0.383
#
# Validation metric: 77.500
# Training loss iter 8000 loss: 0.431
# Saving best model at 80.357
#
# Validation metric: 80.357
# Training loss iter 8500 loss: 0.430
#
# Validation metric: 77.857
# Training loss iter 9000 loss: 0.331
# Saving best model at 80.714
#
# Validation metric: 80.714
# Training loss iter 9500 loss: 0.345
#
# Validation metric: 80.357
# Training loss iter 10000 loss: 0.372
#
# Validation metric: 77.500
# Training loss iter 10500 loss: 0.278
# Saving best model at 85.000
#
# Validation metric: 85.000
# Training loss iter 11000 loss: 0.313
#
# Validation metric: 82.143
# Training loss iter 11500 loss: 0.304
#
# Validation metric: 82.857
# Training loss iter 12000 loss: 0.281
#
# Validation metric: 82.143
# Training loss iter 12500 loss: 0.228
# Saving best model at 85.357
#
# Validation metric: 85.357
# Training loss iter 13000 loss: 0.265
#
# Validation metric: 79.286
# Training loss iter 13500 loss: 0.249
# Saving best model at 85.714
#
# Validation metric: 85.714
# Training loss iter 14000 loss: 0.182
#
# Validation metric: 85.714
# Training loss iter 14500 loss: 0.233
#
# Validation metric: 82.143
# Training loss iter 15000 loss: 0.235
#
# Validation metric: 81.786
# Training loss iter 15500 loss: 0.159
#
# Validation metric: 82.500
# Training loss iter 16000 loss: 0.198
#
# Validation metric: 78.929
# Training loss iter 16500 loss: 0.184
#
# Validation metric: 85.714
# Training loss iter 17000 loss: 0.113
#
# Validation metric: 85.357
# Training loss iter 17500 loss: 0.171
#
# Validation metric: 85.000
# Training loss iter 18000 loss: 0.163
#
# Validation metric: 85.714
# Training loss iter 18500 loss: 0.126
#
# Validation metric: 85.714
# Training loss iter 19000 loss: 0.134
#
# Validation metric: 83.214
# Training loss iter 19500 loss: 0.118
# Saving best model at 87.143
#
# Validation metric: 87.143
# Training loss iter 20000 loss: 0.146
#
# Validation metric: 85.000
# Training loss iter 20500 loss: 0.105
# Saving best model at 87.500
#
# Validation metric: 87.500
# Training loss iter 21000 loss: 0.075
#
# Validation metric: 82.143
# Training loss iter 21500 loss: 0.062
#
# Validation metric: 83.929
# Training loss iter 22000 loss: 0.106
#
# Validation metric: 85.714
# Training loss iter 22500 loss: 0.090
#
# Validation metric: 82.143
# Training loss iter 23000 loss: 0.051
#
# Validation metric: 86.786
# Training loss iter 23500 loss: 0.247
#
# Validation metric: 87.500
# Training loss iter 24000 loss: 0.069
#
# Validation metric: 81.429
# Training loss iter 24500 loss: 0.086
#
# Validation metric: 85.357
# Training loss iter 25000 loss: 0.116
#
# Validation metric: 86.071
# Training loss iter 25500 loss: 0.139
#
# Validation metric: 87.143
# Training loss iter 26000 loss: 0.051
# Saving best model at 88.571
#
# Validation metric: 88.571
# Training loss iter 26500 loss: 0.119
#
# Validation metric: 81.786
# Training loss iter 27000 loss: 0.045
#
# Validation metric: 82.857
# Training loss iter 27500 loss: 0.055
#
# Validation metric: 85.714
# Training loss iter 28000 loss: 0.129
#
# Validation metric: 86.071
# Training loss iter 28500 loss: 0.078
#
# Validation metric: 85.000
# Training loss iter 29000 loss: 0.064
#
# Validation metric: 88.571
# Training loss iter 29500 loss: 0.153
#
# Validation metric: 83.214
# Training loss iter 30000 loss: 0.078
#
# Validation metric: 81.429
# Training loss iter 30500 loss: 0.064
#
# Validation metric: 86.071
# Training loss iter 31000 loss: 0.071
#
# Validation metric: 85.000
# Training loss iter 31500 loss: 0.067
#
# Validation metric: 85.714
# Training loss iter 32000 loss: 0.041
#
# Validation metric: 87.500
# Training loss iter 32500 loss: 0.103
#
# Validation metric: 83.929
# Training loss iter 33000 loss: 0.053
#
# Validation metric: 86.071
# Training loss iter 33500 loss: 0.184
#
# Validation metric: 85.357
# Training loss iter 34000 loss: 0.088
#
# Validation metric: 87.500
# Training loss iter 34500 loss: 0.026
#
# Validation metric: 85.714
# Training loss iter 35000 loss: 0.036
# Saving best model at 91.071
#
# Validation metric: 91.071
# Training loss iter 35500 loss: 0.130
#
# Validation metric: 89.286
# Training loss iter 36000 loss: 0.026
#
# Validation metric: 88.214
# Training loss iter 36500 loss: 0.040
#
# Validation metric: 90.000
# Training loss iter 37000 loss: 0.061
#
# Validation metric: 65.714
# Training loss iter 37500 loss: 0.146
#
# Validation metric: 84.286
# Finished Training
