# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from models.miniNet import MiniNet

# %%
model = MiniNet()

# %%
input = torch.rand(1,1, 64, 64)
out = model(input)

# %%
import os

# %%
list(os.scandir(os.path.join("data/")))[0].name
# Out:
# 'non-COVID'

# %%
import fnmatch

# %%
files = fnmatch.filter(os.listdir("data/COVID"), '*.png')
label = [1]*len(files)

# %%
files

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(files, label, test_size=0.25, random_state=1)

# %%
len(X_test)

# %%
help(dir)

# %%
# Out:
# ['Covid (1158).png',
#  'Covid (251).png',
#  'Covid (710).png',
#  'Covid (994).png',
#  'Covid (342).png',
#  'Covid (1196).png',
#  'Covid (865).png',
#  'Covid (882).png',
#  'Covid (677).png',
#  'Covid (215).png',
#  'Covid (1091).png',
#  'Covid (584).png',
#  'Covid (659).png',
#  'Covid (49).png',
#  'Covid (438).png',
#  'Covid (1209).png',
#  'Covid (770).png',
#  'Covid (585).png',
#  'Covid (83).png',
#  'Covid (1120).png',
#  'Covid (872).png',
#  'Covid (977).png',
#  'Covid (262).png',
#  'Covid (420).png',
#  'Covid (356).png',
#  'Covid (631).png',
#  'Covid (636).png',
#  'Covid (967).png',
#  'Covid (1178).png',
#  'Covid (479).png',
#  'Covid (721).png',
#  'Covid (1221).png',
#  'Covid (156).png',
#  'Covid (962).png',
#  'Covid (707).png',
#  'Covid (76).png',
#  'Covid (11).png',
#  'Covid (830).png',
#  'Covid (470).png',
#  'Covid (37).png',
#  'Covid (354).png',
#  'Covid (533).png',
#  'Covid (620).png',
#  'Covid (1214).png',
#  'Covid (874).png',
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(files, label, test_size=0.25, random_state=1)

# %%
len(X_test)
# Out:
# 313

# %%
help(dir)
# Out:
# Help on built-in function dir in module builtins:
#
# dir(...)
#     dir([object]) -> list of strings
#
#     If called without an argument, return the names in the current scope.
#     Else, return an alphabetized list of names comprising (some of) the attributes
#     of the given object, and of attributes reachable from it.
#     If the object supplies a method named __dir__, it will be used; otherwise
#     the default dir() logic is used and returns:
#       for a module object: the module's attributes.
#       for a class object:  its attributes, and recursively the attributes
#         of its bases.
#       for any other object: its attributes, its class's attributes, and
#         recursively the attributes of its class's base classes.
