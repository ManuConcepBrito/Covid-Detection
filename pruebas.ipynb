# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import numpy as np
from models.miniNet import MiniNet
import matplotlib.pyplot as plt
from torchvision import transforms
from datasets.covidDataset import CovidDataset

# %%
net = MiniNet()

# %%
covid_data = CovidDataset("utils", phase='train', transform=transforms.FiveCrop((150,150)))

# %%
img, label = covid_data[922]

# %%
out = net(img)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-3a273ff48614> in <module>
# ----> 1 out = net(img)
#
# ~/miniconda3/envs/mlgs/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/PycharmProjects/Pytorch-Projects/models/miniNet.py in forward(self, x)
#      27         x = F.relu(self.conv4(x))
#      28         x = F.relu(self.conv5(x))
# ---> 29         x = self.fc1(x.view(-1))
#      30         return torch.sigmoid(x)
#
# ~/miniconda3/envs/mlgs/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
# ...

# %%
img.view(-1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-5d4f54ff346a> in <module>
# ----> 1 img.view(-1)
#
# RuntimeError: view size is not compatible with input tensor's size and stride (at least one dimension spans across two contiguous subspaces). Use .reshape(...) instead.

# %%
230*4
# Out:
# 920

# %%
img_np_trans = img_np.transpose((3, 2, 1, 0))

# %%
plt.imshow(img_np_trans[0,0])

# %%
img_stack.shape
# Out:
# (3000, 1, 150)

# %%
out = net(img_stack)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-87feaf5f726f> in <module>
# ----> 1 out = net(img_stack)
#
# ~/miniconda3/envs/mlgs/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/PycharmProjects/Pytorch-Projects/models/miniNet.py in forward(self, x)
#      20
#      21     def forward(self, x):
# ---> 22         x = F.max_pool2d(F.relu(self.batch_norm1(self.conv1(x))), (2, 2))
#      23         x = F.max_pool2d(F.relu(self.batch_norm2(self.conv2(x))), (2, 2))
# ...
